# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima import auto_arima, AutoARIMA
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from pmdarima.arima import ADFTest 
from statsmodels.tools.eval_measures import rmse
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
from pmdarima.arima import OCSBTest, ADFTest, ndiffs
from shutil import copy2
import warnings
# %matplotlib inline

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1) 

warnings.filterwarnings('ignore')

# %%
# Read file
path = "./datasets/"
name = "p2" # select dataset

df = pd.read_csv(path + name + "_clipped.csv", encoding='utf8', parse_dates=True, index_col="DATE")
validation = pd.read_csv(path + name + "_validation.csv", encoding='utf8', parse_dates=True, index_col="DATE")

cols = df.columns
col = cols[3] # select variable
series = df[col]

# %% [markdown]
# ## Verificação de Estacionareidade pelo teste ADF (Augmented Dickey-Fuller) e Número de Diferenciações por KPSS (Kwiatkowski – Phillips – Schmidt – Shin)

# %%
adf_test = ADFTest(alpha = 0.05)
adf = pd.DataFrame()
diff = pd.DataFrame()

for c in cols:
    adf[c] = adf_test.should_diff(df[c])
    diff[c] = [ndiffs(df[c], alpha=.05, test='kpss', max_d=2)]

adf = adf.T.rename(columns = {0: "adf_pval", 1: "non_stationary"})
diff = diff.T.rename(columns = {0: "d"})
diff = diff.T
adf = adf.T
adf = adf.append(diff)
adf
# Out:
#                      DQO  COLIFORMES_TERMOTOLERANTES  FÓSFORO  NITROGÊNIO  \
# adf_pval        0.023624  0.043021                    0.01     0.0381
# non_stationary  0.000000  0.000000                    0.00     0.0000
# d               0.000000  1.000000                    1.00     0.0000
#
#                  DBO        PH  SURFACTANTES   SÓLIDOS     ÓLEOS  \
# adf_pval        0.01  0.014383  0.032542      0.490253  0.083356
# non_stationary  0.00  0.000000  0.000000      1.000000  1.000000
# d               0.00  0.000000  1.000000      0.000000  0.000000
#
#                 COR_VERDADEIRA
# adf_pval        0.095539
# non_stationary  1.000000
# d               1.000000

# %% [markdown]
# ## Validação
# Para executar a validação vamos realizar fit em todo o conjunto disponível de dados e verificar a aproximação com os dados de validação da série histórica.

# %%
# train/test split
train = series 
test = validation[col]

# plot figures
plt.figure(figsize=(8, 4))
plt.plot(train, color="blue", label="Treino")
plt.plot(test, color="orange", label="Validação")
plt.legend(loc="upper left");
plt.title(f"Série Temporal {col}");

# %%
arima_model = auto_arima(
    train,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=626.707, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=605.397, Time=0.38 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=604.884, Time=0.32 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=624.708, Time=0.02 sec
#  ARIMA(0,0,1)(0,1,0)[12] intercept   : AIC=616.933, Time=0.08 sec
#  ARIMA(0,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(0,0,1)(0,1,2)[12] intercept   : AIC=inf, Time=2.10 sec
#  ARIMA(0,0,1)(1,1,0)[12] intercept   : AIC=609.964, Time=0.32 sec
#  ARIMA(0,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=2.66 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=613.889, Time=0.18 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=599.224, Time=0.34 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=610.773, Time=0.10 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=600.862, Time=0.65 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=600.867, Time=1.20 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=603.784, Time=0.44 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=3.10 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=600.123, Time=0.31 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=600.696, Time=0.54 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=599.488, Time=0.54 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=603.555, Time=0.57 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=598.996, Time=0.37 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=610.186, Time=0.10 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=600.638, Time=0.66 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=600.662, Time=1.20 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=602.843, Time=0.46 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=2.88 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=599.990, Time=0.59 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=600.483, Time=0.69 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=597.053, Time=0.30 sec
#  ARIMA(2,0,0)(0,1,0)[12]             : AIC=608.296, Time=0.05 sec
#  ARIMA(2,0,0)(1,1,1)[12]             : AIC=598.727, Time=0.63 sec
#  ARIMA(2,0,0)(0,1,2)[12]             : AIC=598.746, Time=0.78 sec
#  ARIMA(2,0,0)(1,1,0)[12]             : AIC=600.905, Time=0.16 sec
#  ARIMA(2,0,0)(1,1,2)[12]             : AIC=inf, Time=2.88 sec
#  ARIMA(1,0,0)(0,1,1)[12]             : AIC=598.123, Time=0.17 sec
#  ARIMA(3,0,0)(0,1,1)[12]             : AIC=598.152, Time=0.44 sec
#  ARIMA(2,0,1)(0,1,1)[12]             : AIC=598.786, Time=0.40 sec
#  ARIMA(1,0,1)(0,1,1)[12]             : AIC=597.317, Time=0.31 sec
#  ARIMA(3,0,1)(0,1,1)[12]             : AIC=598.654, Time=0.79 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12]
# Total fit time: 28.702 seconds

# %%
print(arima_model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   84
# Model:             SARIMAX(2, 0, 0)x(0, 1, [1], 12)   Log Likelihood                -294.527
# Date:                              Thu, 05 Nov 2020   AIC                            597.053
# Time:                                      20:12:00   BIC                            606.160
# Sample:                                           0   HQIC                           600.679
#                                                - 84
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3727      0.113      3.310      0.001       0.152       0.593
# ar.L2          0.2190      0.156      1.405      0.160      -0.087       0.525
# ma.S.L12      -0.6269      0.197     -3.183      0.001      -1.013      -0.241
# sigma2       191.6746     38.326      5.001      0.000     116.556     266.793
# ===================================================================================
# Ljung-Box (Q):                       31.03   Jarque-Bera (JB):                 1.02
# Prob(Q):                              0.84   Prob(JB):                         0.60
# Heteroskedasticity (H):               1.20   Skew:                             0.29
# Prob(H) (two-sided):                  0.65   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_model.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Diagnostics");

# %%
fitted = pd.Series(arima_model.arima_res_.fittedvalues, index=train.index)
prediction = pd.DataFrame()
prediction = pd.DataFrame(arima_model.predict(n_periods=len(validation)), index=test.index)
prediction.columns = ['predicted']

plt.figure(figsize=(8, 5))
plt.plot(train, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(fitted, color="darkblue", label="ARIMA")
plt.plot(test, color="orange", label="Validação")
plt.plot(prediction, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA")
plt.legend(loc="upper left");

# %% [markdown]
# ### Modelo 2 -- ARIMA com Transformação de Box-Cox

# %%
from sklearn.preprocessing import PowerTransformer 

scaler = PowerTransformer(method="box-cox")
series_scaled = scaler.fit_transform(train.values.reshape(-1, 1))

# %%
arima_scaled = auto_arima(
    series_scaled,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=218.178, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=194.523, Time=0.29 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=194.603, Time=0.35 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=216.208, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=199.678, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=193.544, Time=0.53 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=193.486, Time=1.45 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=191.413, Time=2.71 sec
#  ARIMA(1,0,0)(5,1,0)[12] intercept   : AIC=193.373, Time=3.72 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=193.381, Time=5.56 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=193.175, Time=4.56 sec
#  ARIMA(1,0,0)(5,1,1)[12] intercept   : AIC=195.274, Time=12.60 sec
#  ARIMA(0,0,0)(4,1,0)[12] intercept   : AIC=206.923, Time=1.82 sec
#  ARIMA(2,0,0)(4,1,0)[12] intercept   : AIC=189.454, Time=3.06 sec
#  ARIMA(2,0,0)(3,1,0)[12] intercept   : AIC=192.177, Time=1.69 sec
#  ARIMA(2,0,0)(5,1,0)[12] intercept   : AIC=inf, Time=5.56 sec
#  ARIMA(2,0,0)(4,1,1)[12] intercept   : AIC=190.914, Time=10.18 sec
#  ARIMA(2,0,0)(3,1,1)[12] intercept   : AIC=192.504, Time=7.76 sec
#  ARIMA(2,0,0)(5,1,1)[12] intercept   : AIC=192.387, Time=20.32 sec
#  ARIMA(3,0,0)(4,1,0)[12] intercept   : AIC=190.303, Time=4.63 sec
#  ARIMA(2,0,1)(4,1,0)[12] intercept   : AIC=191.106, Time=5.06 sec
#  ARIMA(1,0,1)(4,1,0)[12] intercept   : AIC=189.832, Time=4.82 sec
#  ARIMA(3,0,1)(4,1,0)[12] intercept   : AIC=190.477, Time=6.85 sec
#  ARIMA(2,0,0)(4,1,0)[12]             : AIC=187.912, Time=2.84 sec
#  ARIMA(2,0,0)(3,1,0)[12]             : AIC=190.341, Time=1.40 sec
#  ARIMA(2,0,0)(5,1,0)[12]             : AIC=inf, Time=4.76 sec
#  ARIMA(2,0,0)(4,1,1)[12]             : AIC=189.426, Time=6.37 sec
#  ARIMA(2,0,0)(3,1,1)[12]             : AIC=190.815, Time=5.21 sec
#  ARIMA(2,0,0)(5,1,1)[12]             : AIC=inf, Time=17.58 sec
#  ARIMA(1,0,0)(4,1,0)[12]             : AIC=189.575, Time=2.06 sec
#  ARIMA(3,0,0)(4,1,0)[12]             : AIC=188.913, Time=3.25 sec
#  ARIMA(2,0,1)(4,1,0)[12]             : AIC=189.626, Time=3.55 sec
#  ARIMA(1,0,1)(4,1,0)[12]             : AIC=188.310, Time=3.41 sec
#  ARIMA(3,0,1)(4,1,0)[12]             : AIC=189.047, Time=4.59 sec
#
# Best model:  ARIMA(2,0,0)(4,1,0)[12]
# Total fit time: 158.690 seconds

# %%
arima_scaled.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Scaled Diagnostics");

# %%
scale_fitted = pd.Series(arima_scaled.arima_res_.fittedvalues, index=train.index)
prediction_scaled = pd.DataFrame()
prediction_scaled = arima_scaled.predict(n_periods=len(validation))
prediction_scaled_series = pd.Series(prediction_scaled, index=test.index)
prediction_scaled_series.columns = ['predicted']
series_scaled_idx = pd.Series(series_scaled.reshape(1, -1)[0], index=train.index)
test_scaled_idx = pd.Series(scaler.transform(test.values.reshape(-1, 1)).reshape(1, -1)[0], index=test.index)

plt.figure(figsize=(8, 5))
plt.plot(series_scaled_idx, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(scale_fitted, color="darkblue", label="ARIMA")
plt.plot(test_scaled_idx, color="orange", label="Validação")
plt.plot(prediction_scaled_series, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA (Boxcox)")
plt.legend(loc="upper left");

# %%
inverted_prediction = scaler.inverse_transform(prediction_scaled.reshape(-1, 1))
inverted_prediction_series = pd.Series(inverted_prediction.reshape(1, -1)[0], index=test.index)

# %%
plt.figure(figsize=(8, 4))
plt.plot(test, color="orange", label="Valor Verdadeiro")
plt.plot(inverted_prediction_series, linestyle="--", color="magenta", label="Pred. com Boxcox")
plt.plot(prediction, linestyle="--", color="blue", label="Pred. sem Scaler")
plt.title(f"Comparação Predição de {col}")
plt.legend(loc="upper left");

# %%
metrics_df = pd.DataFrame({
    "sarima": round(rmse(test, prediction.values.flatten()), 3),
    "boxcox_sarima": round(rmse(test, inverted_prediction_series), 3)
}, index=["RMSE"])
metrics_df = metrics_df.T.sort_values("RMSE")
best_fit_name = metrics_df.reset_index()['index'][0]
metrics_df
# Out:
#                  RMSE
# sarima         17.582
# boxcox_sarima  20.625

# %%
boxcox_sarima = inverted_prediction_series
boxcox_sarima.name = col 
sarima = pd.Series(prediction['predicted'], index=validation.index)
sarima.name = col
arima = eval(best_fit_name)
# %store arima
# Out:
# Stored 'arima' (Series)

# %%
copy2("arima.ipynb", f"./models/arima/{name}_{col}.ipynb")
# Out:
# './models/arima/p2_NITROGÊNIO.ipynb'

# %%
arima_reset = arima.reset_index()
arima_reset.to_csv(f"./models/forecasts/{name}_{col}_arima.csv", sep=",", encoding="utf8", index=False)
