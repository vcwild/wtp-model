# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima import auto_arima, AutoARIMA
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from pmdarima.arima import ADFTest 
from statsmodels.tools.eval_measures import rmse
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
from pmdarima.arima import OCSBTest, ADFTest, ndiffs
from shutil import copy2
import warnings
# %matplotlib inline

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1) 

warnings.filterwarnings('ignore')

# %%
# Read file
path = "./datasets/"
name = "p1"

df = pd.read_csv(path + name + "_clipped.csv", encoding='utf8', parse_dates=True, index_col="DATE")
validation = pd.read_csv(path + name + "_validation.csv", encoding='utf8', parse_dates=True, index_col="DATE")

cols = df.columns
col = cols[8]
series = df[col]

# %% [markdown]
# ## Verificação de Estacionareidade pelo teste ADF (Augmented Dickey-Fuller) e Número de Diferenciações por KPSS (Kwiatkowski – Phillips – Schmidt – Shin)

# %%
adf_test = ADFTest(alpha = 0.05)
adf = pd.DataFrame()
diff = pd.DataFrame()

for c in cols:
    adf[c] = adf_test.should_diff(df[c])
    diff[c] = [ndiffs(df[c], alpha=.05, test='kpss', max_d=2)]

adf = adf.T.rename(columns = {0: "adf_pval", 1: "non_stationary"})
diff = diff.T.rename(columns = {0: "d"})
diff = diff.T
adf = adf.T
adf = adf.append(diff)
adf
# Out:
#             COLIFORMES_TERMOTOLERANTES       DQO  FÓSFORO  NITROGÊNIO  \
# adf_pval    0.36384                     0.038264  0.24594  0.178183
# stationary  1.00000                     0.000000  1.00000  1.000000
# d           1.00000                     0.000000  0.00000  0.000000
#
#                  DBO    PH  SURFACTANTES   SÓLIDOS     ÓLEOS  COR_VERDADEIRA
# adf_pval    0.076369  0.01  0.085174      0.083784  0.228793  0.01
# stationary  1.000000  0.00  1.000000      1.000000  1.000000  0.00
# d           0.000000  0.00  0.000000      1.000000  0.000000  1.00

# %% [markdown]
# ## Validação
# Para executar a validação vamos realizar fit em todo o conjunto disponível de dados e verificar a aproximação com os dados de validação da série histórica.

# %%
# train/test split
train = series 
test = validation[col]

# plot figures
plt.figure(figsize=(8, 4))
plt.plot(train, color="blue", label="Treino")
plt.plot(test, color="orange", label="Validação")
plt.legend(loc="upper left");
plt.title(f"Série Temporal {col}");
# Out:
# &lt;Figure size 576x288 with 1 Axes&gt;

# %%
arima_model = auto_arima(
    train,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=647.923, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=630.272, Time=0.62 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.35 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=646.589, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=649.726, Time=0.07 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=627.438, Time=1.66 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=628.072, Time=3.04 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=3.46 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.37 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=6.32 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=627.621, Time=0.72 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=626.878, Time=1.66 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=630.374, Time=0.63 sec
#  ARIMA(2,0,0)(3,1,0)[12] intercept   : AIC=627.821, Time=2.92 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=4.56 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=2.29 sec
#  ARIMA(2,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=8.81 sec
#  ARIMA(3,0,0)(2,1,0)[12] intercept   : AIC=626.187, Time=2.57 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=629.024, Time=1.06 sec
#  ARIMA(3,0,0)(3,1,0)[12] intercept   : AIC=627.434, Time=5.26 sec
#  ARIMA(3,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=5.11 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=2.00 sec
#  ARIMA(3,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=9.83 sec
#  ARIMA(4,0,0)(2,1,0)[12] intercept   : AIC=615.103, Time=1.83 sec
#  ARIMA(4,0,0)(1,1,0)[12] intercept   : AIC=622.196, Time=1.32 sec
#  ARIMA(4,0,0)(3,1,0)[12] intercept   : AIC=615.665, Time=8.07 sec
#  ARIMA(4,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=7.49 sec
#  ARIMA(4,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=3.07 sec
#  ARIMA(4,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=11.11 sec
#  ARIMA(5,0,0)(2,1,0)[12] intercept   : AIC=617.103, Time=3.52 sec
#  ARIMA(4,0,1)(2,1,0)[12] intercept   : AIC=617.103, Time=3.66 sec
#  ARIMA(3,0,1)(2,1,0)[12] intercept   : AIC=622.490, Time=4.79 sec
#  ARIMA(5,0,1)(2,1,0)[12] intercept   : AIC=619.103, Time=4.14 sec
#  ARIMA(4,0,0)(2,1,0)[12]             : AIC=613.650, Time=1.13 sec
#  ARIMA(4,0,0)(1,1,0)[12]             : AIC=620.711, Time=0.61 sec
#  ARIMA(4,0,0)(3,1,0)[12]             : AIC=614.166, Time=3.05 sec
#  ARIMA(4,0,0)(2,1,1)[12]             : AIC=inf, Time=4.89 sec
#  ARIMA(4,0,0)(1,1,1)[12]             : AIC=inf, Time=2.44 sec
#  ARIMA(4,0,0)(3,1,1)[12]             : AIC=inf, Time=10.47 sec
#  ARIMA(3,0,0)(2,1,0)[12]             : AIC=625.099, Time=1.58 sec
#  ARIMA(5,0,0)(2,1,0)[12]             : AIC=615.650, Time=2.71 sec
#  ARIMA(4,0,1)(2,1,0)[12]             : AIC=615.650, Time=2.57 sec
#  ARIMA(3,0,1)(2,1,0)[12]             : AIC=621.388, Time=2.95 sec
#  ARIMA(5,0,1)(2,1,0)[12]             : AIC=617.416, Time=5.22 sec
#
# Best model:  ARIMA(4,0,0)(2,1,0)[12]
# Total fit time: 152.043 seconds

# %%
print(arima_model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   84
# Model:             SARIMAX(4, 0, 0)x(2, 1, 0, 12)   Log Likelihood                -299.825
# Date:                            Thu, 08 Oct 2020   AIC                            613.650
# Time:                                    11:48:17   BIC                            629.587
# Sample:                                         0   HQIC                           619.995
#                                              - 84
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P&gt;|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2763      0.116      2.384      0.017       0.049       0.504
# ar.L2          0.1529      0.092      1.662      0.096      -0.027       0.333
# ar.L3         -0.2519      0.137     -1.841      0.066      -0.520       0.016
# ar.L4          0.4345      0.121      3.596      0.000       0.198       0.671
# ar.S.L12      -0.7874      0.124     -6.328      0.000      -1.031      -0.544
# ar.S.L24      -0.4193      0.155     -2.710      0.007      -0.722      -0.116
# sigma2       211.7654     36.209      5.848      0.000     140.798     282.733
# ===================================================================================
# Ljung-Box (Q):                       48.35   Jarque-Bera (JB):                12.20
# Prob(Q):                              0.17   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.38   Skew:                             0.86
# Prob(H) (two-sided):                  0.44   Kurtosis:                         4.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_model.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Diagnostics");
# Out:
# &lt;Figure size 720x576 with 4 Axes&gt;

# %%
fitted = pd.Series(arima_model.arima_res_.fittedvalues, index=train.index)
prediction = pd.DataFrame()
prediction = pd.DataFrame(arima_model.predict(n_periods=len(validation)), index=test.index)
prediction.columns = ['predicted']

plt.figure(figsize=(8, 5))
plt.plot(train, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(fitted, color="darkblue", label="ARIMA")
plt.plot(test, color="orange", label="Validação")
plt.plot(prediction, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x360 with 1 Axes&gt;

# %% [markdown]
# ### Modelo 2 -- ARIMA com Transformação de Box-Cox

# %%
from sklearn.preprocessing import PowerTransformer 

scaler = PowerTransformer(method="box-cox")
series_scaled = scaler.fit_transform(train.values.reshape(-1, 1))

# %%
arima_scaled = auto_arima(
    series_scaled,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=244.385, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=225.736, Time=0.35 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=244.415, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=246.366, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=223.865, Time=0.58 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=225.399, Time=1.21 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=3.41 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.53 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=7.97 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=223.370, Time=0.51 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=224.596, Time=0.30 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=224.746, Time=1.36 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=225.448, Time=1.31 sec
#  ARIMA(0,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=2.18 sec
#  ARIMA(0,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=6.62 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=224.357, Time=0.57 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=220.935, Time=2.16 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=224.445, Time=0.82 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=222.406, Time=4.17 sec
#  ARIMA(1,0,1)(2,1,1)[12] intercept   : AIC=inf, Time=4.11 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=2.42 sec
#  ARIMA(1,0,1)(3,1,1)[12] intercept   : AIC=224.694, Time=8.19 sec
#  ARIMA(2,0,1)(2,1,0)[12] intercept   : AIC=222.316, Time=2.03 sec
#  ARIMA(1,0,2)(2,1,0)[12] intercept   : AIC=222.576, Time=1.52 sec
#  ARIMA(0,0,2)(2,1,0)[12] intercept   : AIC=222.448, Time=0.70 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=222.449, Time=0.74 sec
#  ARIMA(2,0,2)(2,1,0)[12] intercept   : AIC=224.290, Time=2.63 sec
#  ARIMA(1,0,1)(2,1,0)[12]             : AIC=219.754, Time=1.25 sec
#  ARIMA(1,0,1)(1,1,0)[12]             : AIC=223.271, Time=0.50 sec
#  ARIMA(1,0,1)(3,1,0)[12]             : AIC=221.244, Time=2.89 sec
#  ARIMA(1,0,1)(2,1,1)[12]             : AIC=inf, Time=3.47 sec
#  ARIMA(1,0,1)(1,1,1)[12]             : AIC=inf, Time=1.26 sec
#  ARIMA(1,0,1)(3,1,1)[12]             : AIC=inf, Time=6.10 sec
#  ARIMA(0,0,1)(2,1,0)[12]             : AIC=226.634, Time=0.30 sec
#  ARIMA(1,0,0)(2,1,0)[12]             : AIC=225.622, Time=0.31 sec
#  ARIMA(2,0,1)(2,1,0)[12]             : AIC=223.434, Time=0.74 sec
#  ARIMA(1,0,2)(2,1,0)[12]             : AIC=224.304, Time=0.71 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : AIC=226.420, Time=0.18 sec
#  ARIMA(0,0,2)(2,1,0)[12]             : AIC=223.497, Time=0.38 sec
#  ARIMA(2,0,0)(2,1,0)[12]             : AIC=223.157, Time=0.38 sec
#  ARIMA(2,0,2)(2,1,0)[12]             : AIC=221.414, Time=2.24 sec
#
# Best model:  ARIMA(1,0,1)(2,1,0)[12]
# Total fit time: 78.952 seconds

# %%
arima_scaled.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Scaled Diagnostics");
# Out:
# &lt;Figure size 720x576 with 4 Axes&gt;

# %%
scale_fitted = pd.Series(arima_scaled.arima_res_.fittedvalues, index=train.index)
prediction_scaled = pd.DataFrame()
prediction_scaled = arima_scaled.predict(n_periods=len(validation))
prediction_scaled_series = pd.Series(prediction_scaled, index=test.index)
prediction_scaled_series.columns = ['predicted']
series_scaled_idx = pd.Series(series_scaled.reshape(1, -1)[0], index=train.index)
test_scaled_idx = pd.Series(scaler.transform(test.values.reshape(-1, 1)).reshape(1, -1)[0], index=test.index)

plt.figure(figsize=(8, 5))
plt.plot(series_scaled_idx, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(scale_fitted, color="darkblue", label="ARIMA")
plt.plot(test_scaled_idx, color="orange", label="Validação")
plt.plot(prediction_scaled_series, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA (Boxcox)")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x360 with 1 Axes&gt;

# %%
inverted_prediction = scaler.inverse_transform(prediction_scaled.reshape(-1, 1))
inverted_prediction_series = pd.Series(inverted_prediction.reshape(1, -1)[0], index=test.index)

# %%
plt.figure(figsize=(8, 4))
plt.plot(test, color="orange", label="Valor Verdadeiro")
plt.plot(inverted_prediction_series, linestyle="--", color="green", label="Pred. com Boxcox")
plt.plot(prediction, linestyle="--", color="blue", label="Pred. sem Scaler")
plt.title(f"Comparação Predição de {col}")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x288 with 1 Axes&gt;

# %%
metrics_df = pd.DataFrame({
    "sarima": round(rmse(test, prediction.values.flatten()), 3),
    "boxcox_sarima": round(rmse(test, inverted_prediction_series), 3)
}, index=["RMSE"])
metrics_df = metrics_df.T.sort_values("RMSE")
best_fit_name = metrics_df.reset_index()['index'][0]
metrics_df
# Out:
#                  RMSE
# boxcox_sarima  10.388
# sarima         15.205

# %%
boxcox_sarima = inverted_prediction_series
boxcox_sarima.name = col 
sarima = pd.Series(prediction['predicted'], index=validation.index)
sarima.name = col
arima = eval(best_fit_name)
# %store arima
# Out:
# Stored &#39;arima&#39; (Series)

# %%
copy2("arima.ipynb", f"./models/arima/{name}_{col}.ipynb")
# Out:
# &#39;./models/arima/p1_ÓLEOS.ipynb&#39;
