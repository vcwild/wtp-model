# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima import auto_arima, AutoARIMA
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from pmdarima.arima import ADFTest 
from statsmodels.tools.eval_measures import rmse
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
from pmdarima.arima import OCSBTest, ADFTest, ndiffs
from shutil import copy2
import warnings
# %matplotlib inline

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1) 

warnings.filterwarnings('ignore')

# %%
# Read file
path = "./datasets/"
name = "p2" # select dataset

df = pd.read_csv(path + name + "_clipped.csv", encoding='utf8', parse_dates=True, index_col="DATE")
validation = pd.read_csv(path + name + "_validation.csv", encoding='utf8', parse_dates=True, index_col="DATE")

cols = df.columns
col = cols[8] # select variable
series = df[col]

# %% [markdown]
# ## Verificação de Estacionareidade pelo teste ADF (Augmented Dickey-Fuller) e Número de Diferenciações por KPSS (Kwiatkowski – Phillips – Schmidt – Shin)

# %%
adf_test = ADFTest(alpha = 0.05)
adf = pd.DataFrame()
diff = pd.DataFrame()

for c in cols:
    adf[c] = adf_test.should_diff(df[c])
    diff[c] = [ndiffs(df[c], alpha=.05, test='kpss', max_d=2)]

adf = adf.T.rename(columns = {0: "adf_pval", 1: "non_stationary"})
diff = diff.T.rename(columns = {0: "d"})
diff = diff.T
adf = adf.T
adf = adf.append(diff)
adf
# Out:
#                      DQO  COLIFORMES_TERMOTOLERANTES  FÓSFORO  NITROGÊNIO  \
# adf_pval        0.023624  0.043021                    0.01     0.0381
# non_stationary  0.000000  0.000000                    0.00     0.0000
# d               0.000000  1.000000                    1.00     0.0000
#
#                  DBO        PH  SURFACTANTES   SÓLIDOS     ÓLEOS  \
# adf_pval        0.01  0.014383  0.032542      0.490253  0.083356
# non_stationary  0.00  0.000000  0.000000      1.000000  1.000000
# d               0.00  0.000000  1.000000      0.000000  0.000000
#
#                 COR_VERDADEIRA
# adf_pval        0.095539
# non_stationary  1.000000
# d               1.000000

# %% [markdown]
# ## Validação
# Para executar a validação vamos realizar fit em todo o conjunto disponível de dados e verificar a aproximação com os dados de validação da série histórica.

# %%
# train/test split
train = series 
test = validation[col]

# plot figures
plt.figure(figsize=(8, 4))
plt.plot(train, color="blue", label="Treino")
plt.plot(test, color="orange", label="Validação")
plt.legend(loc="upper left");
plt.title(f"Série Temporal {col}");

# %%
arima_model = auto_arima(
    train,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=437.675, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=425.869, Time=0.26 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.68 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=435.699, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=438.726, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=411.256, Time=0.66 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=409.208, Time=1.81 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=inf, Time=3.62 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=5.32 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=2.65 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=10.86 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=407.324, Time=1.50 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=409.324, Time=0.66 sec
#  ARIMA(0,0,0)(4,1,0)[12] intercept   : AIC=inf, Time=3.28 sec
#  ARIMA(0,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=5.69 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=2.16 sec
#  ARIMA(0,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=8.26 sec
#  ARIMA(0,0,1)(3,1,0)[12] intercept   : AIC=409.239, Time=1.42 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=409.954, Time=2.49 sec
#  ARIMA(0,0,0)(3,1,0)[12]             : AIC=408.208, Time=0.54 sec
#
# Best model:  ARIMA(0,0,0)(3,1,0)[12] intercept
# Total fit time: 51.954 seconds

# %%
print(arima_model.summary())
# Out:
#                                 SARIMAX Results
# ================================================================================
# Dep. Variable:                        y   No. Observations:                   84
# Model:             SARIMAX(3, 1, 0, 12)   Log Likelihood                -198.662
# Date:                  Thu, 05 Nov 2020   AIC                            407.324
# Time:                          20:29:32   BIC                            418.707
# Sample:                               0   HQIC                           411.856
#                                    - 84
# Covariance Type:                    opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9240      0.659      1.403      0.161      -0.367       2.215
# ar.S.L12      -0.8937      0.203     -4.409      0.000      -1.291      -0.496
# ar.S.L24      -0.7796      0.209     -3.737      0.000      -1.188      -0.371
# ar.S.L36      -0.2870      0.216     -1.331      0.183      -0.709       0.135
# sigma2        11.7745      1.796      6.554      0.000       8.254      15.295
# ===================================================================================
# Ljung-Box (Q):                       37.18   Jarque-Bera (JB):               217.30
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.84   Skew:                             2.18
# Prob(H) (two-sided):                  0.01   Kurtosis:                        10.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_model.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Diagnostics");

# %%
fitted = pd.Series(arima_model.arima_res_.fittedvalues, index=train.index)
prediction = pd.DataFrame()
prediction = pd.DataFrame(arima_model.predict(n_periods=len(validation)), index=test.index)
prediction.columns = ['predicted']

plt.figure(figsize=(8, 5))
plt.plot(train, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(fitted, color="darkblue", label="ARIMA")
plt.plot(test, color="orange", label="Validação")
plt.plot(prediction, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA")
plt.legend(loc="upper left");

# %% [markdown]
# ### Modelo 2 -- ARIMA com Transformação de Box-Cox

# %%
from sklearn.preprocessing import PowerTransformer 

scaler = PowerTransformer(method="box-cox")
series_scaled = scaler.fit_transform(train.values.reshape(-1, 1))

# %%
arima_scaled = auto_arima(
    series_scaled,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=279.334, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=264.035, Time=0.23 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=277.371, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=281.303, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=254.548, Time=0.54 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=248.605, Time=1.74 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=inf, Time=3.02 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=4.32 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=12.07 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=247.085, Time=0.93 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=253.069, Time=0.45 sec
#  ARIMA(0,0,0)(4,1,0)[12] intercept   : AIC=inf, Time=2.56 sec
#  ARIMA(0,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=4.24 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=1.57 sec
#  ARIMA(0,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=8.05 sec
#  ARIMA(0,0,1)(3,1,0)[12] intercept   : AIC=248.740, Time=1.46 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=250.010, Time=2.24 sec
#  ARIMA(0,0,0)(3,1,0)[12]             : AIC=245.566, Time=0.65 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : AIC=251.151, Time=0.17 sec
#  ARIMA(0,0,0)(4,1,0)[12]             : AIC=inf, Time=1.68 sec
#  ARIMA(0,0,0)(3,1,1)[12]             : AIC=inf, Time=3.14 sec
#  ARIMA(0,0,0)(2,1,1)[12]             : AIC=inf, Time=2.28 sec
#  ARIMA(0,0,0)(4,1,1)[12]             : AIC=inf, Time=6.83 sec
#  ARIMA(1,0,0)(3,1,0)[12]             : AIC=247.236, Time=0.91 sec
#  ARIMA(0,0,1)(3,1,0)[12]             : AIC=247.331, Time=0.86 sec
#  ARIMA(1,0,1)(3,1,0)[12]             : AIC=248.629, Time=1.47 sec
#
# Best model:  ARIMA(0,0,0)(3,1,0)[12]
# Total fit time: 64.567 seconds

# %%
arima_scaled.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Scaled Diagnostics");

# %%
scale_fitted = pd.Series(arima_scaled.arima_res_.fittedvalues, index=train.index)
prediction_scaled = pd.DataFrame()
prediction_scaled = arima_scaled.predict(n_periods=len(validation))
prediction_scaled_series = pd.Series(prediction_scaled, index=test.index)
prediction_scaled_series.columns = ['predicted']
series_scaled_idx = pd.Series(series_scaled.reshape(1, -1)[0], index=train.index)
test_scaled_idx = pd.Series(scaler.transform(test.values.reshape(-1, 1)).reshape(1, -1)[0], index=test.index)

plt.figure(figsize=(8, 5))
plt.plot(series_scaled_idx, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(scale_fitted, color="darkblue", label="ARIMA")
plt.plot(test_scaled_idx, color="orange", label="Validação")
plt.plot(prediction_scaled_series, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA (Boxcox)")
plt.legend(loc="upper left");

# %%
inverted_prediction = scaler.inverse_transform(prediction_scaled.reshape(-1, 1))
inverted_prediction_series = pd.Series(inverted_prediction.reshape(1, -1)[0], index=test.index)

# %%
plt.figure(figsize=(8, 4))
plt.plot(test, color="orange", label="Valor Verdadeiro")
plt.plot(inverted_prediction_series, linestyle="--", color="magenta", label="Pred. com Boxcox")
plt.plot(prediction, linestyle="--", color="blue", label="Pred. sem Scaler")
plt.title(f"Comparação Predição de {col}")
plt.legend(loc="upper left");

# %%
metrics_df = pd.DataFrame({
    "sarima": round(rmse(test, prediction.values.flatten()), 3),
    "boxcox_sarima": round(rmse(test, inverted_prediction_series), 3)
}, index=["RMSE"])
metrics_df = metrics_df.T.sort_values("RMSE")
best_fit_name = metrics_df.reset_index()['index'][0]
metrics_df
# Out:
#                 RMSE
# boxcox_sarima  3.098
# sarima         4.052

# %%
boxcox_sarima = inverted_prediction_series
boxcox_sarima.name = col 
sarima = pd.Series(prediction['predicted'], index=validation.index)
sarima.name = col
arima = eval(best_fit_name)
# %store arima
# Out:
# Stored 'arima' (Series)

# %%
copy2("arima.ipynb", f"./models/arima/{name}_{col}.ipynb")
# Out:
# './models/arima/p2_ÓLEOS.ipynb'

# %%
arima_reset = arima.reset_index()
arima_reset.to_csv(f"./models/forecasts/{name}_{col}_arima.csv", sep=",", encoding="utf8", index=False)
