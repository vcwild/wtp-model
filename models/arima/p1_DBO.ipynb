# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima import auto_arima, AutoARIMA
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from pmdarima.arima import ADFTest 
from statsmodels.tools.eval_measures import rmse
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
from pmdarima.arima import OCSBTest, ADFTest, ndiffs
from shutil import copy2
import warnings
# %matplotlib inline

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1) 

warnings.filterwarnings('ignore')

# %%
# Read file
path = "./datasets/"
name = "p1" # select dataset

df = pd.read_csv(path + name + "_clipped.csv", encoding='utf8', parse_dates=True, index_col="DATE")
validation = pd.read_csv(path + name + "_validation.csv", encoding='utf8', parse_dates=True, index_col="DATE")

cols = df.columns
col = cols[4] # select variable
series = df[col]

# %% [markdown]
# ## Verificação de Estacionareidade pelo teste ADF (Augmented Dickey-Fuller) e Número de Diferenciações por KPSS (Kwiatkowski – Phillips – Schmidt – Shin)

# %%
adf_test = ADFTest(alpha = 0.05)
adf = pd.DataFrame()
diff = pd.DataFrame()

for c in cols:
    adf[c] = adf_test.should_diff(df[c])
    diff[c] = [ndiffs(df[c], alpha=.05, test='kpss', max_d=2)]

adf = adf.T.rename(columns = {0: "adf_pval", 1: "non_stationary"})
diff = diff.T.rename(columns = {0: "d"})
diff = diff.T
adf = adf.T
adf = adf.append(diff)
adf
# Out:
#                 COLIFORMES_TERMOTOLERANTES       DQO  FÓSFORO  NITROGÊNIO  \
# adf_pval        0.36384                     0.038264  0.24594  0.178183
# non_stationary  1.00000                     0.000000  1.00000  1.000000
# d               1.00000                     0.000000  0.00000  0.000000
#
#                      DBO    PH  SURFACTANTES   SÓLIDOS     ÓLEOS  \
# adf_pval        0.076369  0.01  0.085174      0.083784  0.228793
# non_stationary  1.000000  0.00  1.000000      1.000000  1.000000
# d               0.000000  0.00  0.000000      1.000000  0.000000
#
#                 COR_VERDADEIRA
# adf_pval        0.01
# non_stationary  0.00
# d               1.00

# %% [markdown]
# ## Validação
# Para executar a validação vamos realizar fit em todo o conjunto disponível de dados e verificar a aproximação com os dados de validação da série histórica.

# %%
# train/test split
train = series 
test = validation[col]

# plot figures
plt.figure(figsize=(8, 4))
plt.plot(train, color="blue", label="Treino")
plt.plot(test, color="orange", label="Validação")
plt.legend(loc="upper left");
plt.title(f"Série Temporal {col}");

# %%
arima_model = auto_arima(
    train,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=845.699, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=830.391, Time=0.56 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=844.196, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=846.628, Time=0.06 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=831.366, Time=0.77 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.19 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=825.322, Time=0.53 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=inf, Time=2.57 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=3.33 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=823.097, Time=0.85 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=840.907, Time=0.12 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=inf, Time=2.00 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=830.030, Time=1.40 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=2.52 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=824.613, Time=1.83 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=824.458, Time=1.39 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.83 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=821.974, Time=0.70 sec
#  ARIMA(2,0,0)(0,1,0)[12]             : AIC=839.136, Time=0.06 sec
#  ARIMA(2,0,0)(1,1,1)[12]             : AIC=inf, Time=0.92 sec
#  ARIMA(2,0,0)(0,1,2)[12]             : AIC=inf, Time=2.25 sec
#  ARIMA(2,0,0)(1,1,0)[12]             : AIC=828.478, Time=0.24 sec
#  ARIMA(2,0,0)(1,1,2)[12]             : AIC=inf, Time=3.27 sec
#  ARIMA(1,0,0)(0,1,1)[12]             : AIC=824.599, Time=0.50 sec
#  ARIMA(3,0,0)(0,1,1)[12]             : AIC=823.501, Time=0.67 sec
#  ARIMA(2,0,1)(0,1,1)[12]             : AIC=823.294, Time=0.69 sec
#  ARIMA(1,0,1)(0,1,1)[12]             : AIC=inf, Time=0.68 sec
#  ARIMA(3,0,1)(0,1,1)[12]             : AIC=inf, Time=1.42 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12]
# Total fit time: 36.156 seconds

# %%
print(arima_model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   84
# Model:             SARIMAX(2, 0, 0)x(0, 1, [1], 12)   Log Likelihood                -406.987
# Date:                              Thu, 05 Nov 2020   AIC                            821.974
# Time:                                      19:40:16   BIC                            831.081
# Sample:                                           0   HQIC                           825.600
#                                                - 84
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1761      0.119      1.474      0.140      -0.058       0.410
# ar.L2          0.2515      0.116      2.173      0.030       0.025       0.478
# ma.S.L12      -0.7850      0.156     -5.023      0.000      -1.091      -0.479
# sigma2      4069.6896    770.092      5.285      0.000    2560.337    5579.043
# ===================================================================================
# Ljung-Box (Q):                       50.26   Jarque-Bera (JB):                 0.88
# Prob(Q):                              0.13   Prob(JB):                         0.64
# Heteroskedasticity (H):               1.02   Skew:                             0.27
# Prob(H) (two-sided):                  0.97   Kurtosis:                         3.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_model.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Diagnostics");

# %%
fitted = pd.Series(arima_model.arima_res_.fittedvalues, index=train.index)
prediction = pd.DataFrame()
prediction = pd.DataFrame(arima_model.predict(n_periods=len(validation)), index=test.index)
prediction.columns = ['predicted']

plt.figure(figsize=(8, 5))
plt.plot(train, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(fitted, color="darkblue", label="ARIMA")
plt.plot(test, color="orange", label="Validação")
plt.plot(prediction, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA")
plt.legend(loc="upper left");

# %% [markdown]
# ### Modelo 2 -- ARIMA com Transformação de Box-Cox

# %%
from sklearn.preprocessing import PowerTransformer 

scaler = PowerTransformer(method="box-cox")
series_scaled = scaler.fit_transform(train.values.reshape(-1, 1))

# %%
arima_scaled = auto_arima(
    series_scaled,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=231.380, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=216.387, Time=0.31 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=230.330, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=232.155, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=216.396, Time=0.87 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=4.16 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=219.541, Time=0.13 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=213.512, Time=0.30 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=224.172, Time=0.06 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=212.875, Time=0.75 sec
#  ARIMA(2,0,0)(3,1,0)[12] intercept   : AIC=208.850, Time=1.70 sec
#  ARIMA(2,0,0)(4,1,0)[12] intercept   : AIC=210.702, Time=2.69 sec
#  ARIMA(2,0,0)(3,1,1)[12] intercept   : AIC=inf, Time=6.15 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=3.17 sec
#  ARIMA(2,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=11.17 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=216.651, Time=1.50 sec
#  ARIMA(3,0,0)(3,1,0)[12] intercept   : AIC=209.708, Time=2.37 sec
#  ARIMA(2,0,1)(3,1,0)[12] intercept   : AIC=209.443, Time=2.24 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=212.675, Time=3.50 sec
#  ARIMA(3,0,1)(3,1,0)[12] intercept   : AIC=211.380, Time=2.88 sec
#  ARIMA(2,0,0)(3,1,0)[12]             : AIC=207.645, Time=1.12 sec
#  ARIMA(2,0,0)(2,1,0)[12]             : AIC=211.583, Time=0.49 sec
#  ARIMA(2,0,0)(4,1,0)[12]             : AIC=209.606, Time=2.52 sec
#  ARIMA(2,0,0)(3,1,1)[12]             : AIC=209.490, Time=3.18 sec
#  ARIMA(2,0,0)(2,1,1)[12]             : AIC=inf, Time=2.32 sec
#  ARIMA(2,0,0)(4,1,1)[12]             : AIC=inf, Time=12.70 sec
#  ARIMA(1,0,0)(3,1,0)[12]             : AIC=215.995, Time=1.18 sec
#  ARIMA(3,0,0)(3,1,0)[12]             : AIC=208.670, Time=1.69 sec
#  ARIMA(2,0,1)(3,1,0)[12]             : AIC=208.344, Time=1.97 sec
#  ARIMA(1,0,1)(3,1,0)[12]             : AIC=211.163, Time=2.50 sec
#  ARIMA(3,0,1)(3,1,0)[12]             : AIC=210.316, Time=2.65 sec
#
# Best model:  ARIMA(2,0,0)(3,1,0)[12]
# Total fit time: 79.116 seconds

# %%
arima_scaled.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Scaled Diagnostics");

# %%
scale_fitted = pd.Series(arima_scaled.arima_res_.fittedvalues, index=train.index)
prediction_scaled = pd.DataFrame()
prediction_scaled = arima_scaled.predict(n_periods=len(validation))
prediction_scaled_series = pd.Series(prediction_scaled, index=test.index)
prediction_scaled_series.columns = ['predicted']
series_scaled_idx = pd.Series(series_scaled.reshape(1, -1)[0], index=train.index)
test_scaled_idx = pd.Series(scaler.transform(test.values.reshape(-1, 1)).reshape(1, -1)[0], index=test.index)

plt.figure(figsize=(8, 5))
plt.plot(series_scaled_idx, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(scale_fitted, color="darkblue", label="ARIMA")
plt.plot(test_scaled_idx, color="orange", label="Validação")
plt.plot(prediction_scaled_series, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA (Boxcox)")
plt.legend(loc="upper left");

# %%
inverted_prediction = scaler.inverse_transform(prediction_scaled.reshape(-1, 1))
inverted_prediction_series = pd.Series(inverted_prediction.reshape(1, -1)[0], index=test.index)

# %%
plt.figure(figsize=(8, 4))
plt.plot(test, color="orange", label="Valor Verdadeiro")
plt.plot(inverted_prediction_series, linestyle="--", color="green", label="Pred. com Boxcox")
plt.plot(prediction, linestyle="--", color="blue", label="Pred. sem Scaler")
plt.title(f"Comparação Predição de {col}")
plt.legend(loc="upper left");

# %%
metrics_df = pd.DataFrame({
    "sarima": round(rmse(test, prediction.values.flatten()), 3),
    "boxcox_sarima": round(rmse(test, inverted_prediction_series), 3)
}, index=["RMSE"])
metrics_df = metrics_df.T.sort_values("RMSE")
best_fit_name = metrics_df.reset_index()['index'][0]
metrics_df
# Out:
#                  RMSE
# sarima         76.814
# boxcox_sarima  81.075

# %%
boxcox_sarima = inverted_prediction_series
boxcox_sarima.name = col 
sarima = pd.Series(prediction['predicted'], index=validation.index)
sarima.name = col
arima = eval(best_fit_name)
# %store arima
# Out:
# Stored 'arima' (Series)

# %%
copy2("arima.ipynb", f"./models/arima/{name}_{col}.ipynb")
# Out:
# './models/arima/p1_DBO.ipynb'

# %%
arima_reset = arima.reset_index()
arima_reset.to_csv(f"./models/forecasts/{name}_{col}_arima.csv", sep=",", encoding="utf8", index=False)
