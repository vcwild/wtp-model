# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima import auto_arima, AutoARIMA
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from pmdarima.arima import ADFTest 
from statsmodels.tools.eval_measures import rmse
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
from pmdarima.arima import OCSBTest, ADFTest, ndiffs
from shutil import copy2
import warnings
# %matplotlib inline

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1) 

warnings.filterwarnings('ignore')

# %%
# Read file
path = "./datasets/"
name = "p1" # select dataset

df = pd.read_csv(path + name + "_clipped.csv", encoding='utf8', parse_dates=True, index_col="DATE")
validation = pd.read_csv(path + name + "_validation.csv", encoding='utf8', parse_dates=True, index_col="DATE")

cols = df.columns
col = cols[3] # select variable
series = df[col]

# %% [markdown]
# ## Verificação de Estacionareidade pelo teste ADF (Augmented Dickey-Fuller) e Número de Diferenciações por KPSS (Kwiatkowski – Phillips – Schmidt – Shin)

# %%
adf_test = ADFTest(alpha = 0.05)
adf = pd.DataFrame()
diff = pd.DataFrame()

for c in cols:
    adf[c] = adf_test.should_diff(df[c])
    diff[c] = [ndiffs(df[c], alpha=.05, test='kpss', max_d=2)]

adf = adf.T.rename(columns = {0: "adf_pval", 1: "non_stationary"})
diff = diff.T.rename(columns = {0: "d"})
diff = diff.T
adf = adf.T
adf = adf.append(diff)
adf
# Out:
#                 COLIFORMES_TERMOTOLERANTES       DQO  FÓSFORO  NITROGÊNIO  \
# adf_pval        0.36384                     0.038264  0.24594  0.178183
# non_stationary  1.00000                     0.000000  1.00000  1.000000
# d               1.00000                     0.000000  0.00000  0.000000
#
#                      DBO    PH  SURFACTANTES   SÓLIDOS     ÓLEOS  \
# adf_pval        0.076369  0.01  0.085174      0.083784  0.228793
# non_stationary  1.000000  0.00  1.000000      1.000000  1.000000
# d               0.000000  0.00  0.000000      1.000000  0.000000
#
#                 COR_VERDADEIRA
# adf_pval        0.01
# non_stationary  0.00
# d               1.00

# %% [markdown]
# ## Validação
# Para executar a validação vamos realizar fit em todo o conjunto disponível de dados e verificar a aproximação com os dados de validação da série histórica.

# %%
# train/test split
train = series 
test = validation[col]

# plot figures
plt.figure(figsize=(8, 4))
plt.plot(train, color="blue", label="Treino")
plt.plot(test, color="orange", label="Validação")
plt.legend(loc="upper left");
plt.title(f"Série Temporal {col}");

# %%
arima_model = auto_arima(
    train,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=600.873, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=574.516, Time=0.43 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=599.599, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=578.319, Time=0.07 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=559.201, Time=0.95 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=558.434, Time=2.33 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=560.427, Time=4.54 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=560.431, Time=2.99 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=558.831, Time=1.51 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=562.433, Time=4.87 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=572.873, Time=1.58 sec
#  ARIMA(2,0,0)(3,1,0)[12] intercept   : AIC=558.539, Time=2.54 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=557.726, Time=3.18 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=557.251, Time=1.18 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=573.044, Time=0.40 sec
#  ARIMA(1,0,1)(2,1,1)[12] intercept   : AIC=558.010, Time=2.36 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=1.30 sec
#  ARIMA(1,0,1)(3,1,1)[12] intercept   : AIC=559.670, Time=4.94 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=565.045, Time=0.95 sec
#  ARIMA(2,0,1)(2,1,0)[12] intercept   : AIC=inf, Time=3.51 sec
#  ARIMA(1,0,2)(2,1,0)[12] intercept   : AIC=558.773, Time=1.72 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=575.132, Time=0.83 sec
#  ARIMA(0,0,2)(2,1,0)[12] intercept   : AIC=564.875, Time=1.70 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=557.810, Time=1.22 sec
#  ARIMA(2,0,2)(2,1,0)[12] intercept   : AIC=557.541, Time=3.70 sec
#  ARIMA(1,0,1)(2,1,0)[12]             : AIC=555.739, Time=0.76 sec
#  ARIMA(1,0,1)(1,1,0)[12]             : AIC=571.365, Time=0.20 sec
#  ARIMA(1,0,1)(3,1,0)[12]             : AIC=556.072, Time=1.61 sec
#  ARIMA(1,0,1)(2,1,1)[12]             : AIC=556.445, Time=1.46 sec
#  ARIMA(1,0,1)(1,1,1)[12]             : AIC=inf, Time=1.60 sec
#  ARIMA(1,0,1)(3,1,1)[12]             : AIC=558.002, Time=3.39 sec
#  ARIMA(0,0,1)(2,1,0)[12]             : AIC=563.305, Time=0.51 sec
#  ARIMA(1,0,0)(2,1,0)[12]             : AIC=557.537, Time=0.40 sec
#  ARIMA(2,0,1)(2,1,0)[12]             : AIC=inf, Time=2.65 sec
#  ARIMA(1,0,2)(2,1,0)[12]             : AIC=557.252, Time=0.69 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : AIC=573.313, Time=0.27 sec
#  ARIMA(0,0,2)(2,1,0)[12]             : AIC=563.181, Time=0.56 sec
#  ARIMA(2,0,0)(2,1,0)[12]             : AIC=556.248, Time=0.68 sec
#  ARIMA(2,0,2)(2,1,0)[12]             : AIC=555.669, Time=2.27 sec
#  ARIMA(2,0,2)(1,1,0)[12]             : AIC=570.186, Time=0.80 sec
#  ARIMA(2,0,2)(3,1,0)[12]             : AIC=556.800, Time=5.28 sec
#  ARIMA(2,0,2)(2,1,1)[12]             : AIC=556.979, Time=3.58 sec
#  ARIMA(2,0,2)(1,1,1)[12]             : AIC=inf, Time=2.33 sec
#  ARIMA(2,0,2)(3,1,1)[12]             : AIC=558.769, Time=6.98 sec
#  ARIMA(3,0,2)(2,1,0)[12]             : AIC=558.888, Time=2.44 sec
#  ARIMA(2,0,3)(2,1,0)[12]             : AIC=559.314, Time=2.73 sec
#  ARIMA(1,0,3)(2,1,0)[12]             : AIC=557.849, Time=1.46 sec
#  ARIMA(3,0,1)(2,1,0)[12]             : AIC=557.261, Time=1.34 sec
#  ARIMA(3,0,3)(2,1,0)[12]             : AIC=560.879, Time=2.20 sec
#
# Best model:  ARIMA(2,0,2)(2,1,0)[12]
# Total fit time: 95.931 seconds

# %%
print(arima_model.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   84
# Model:             SARIMAX(2, 0, 2)x(2, 1, [], 12)   Log Likelihood                -270.835
# Date:                             Thu, 05 Nov 2020   AIC                            555.669
# Time:                                     19:37:08   BIC                            571.606
# Sample:                                          0   HQIC                           562.014
#                                               - 84
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.8531      0.079     23.410      0.000       1.698       2.008
# ar.L2         -0.9216      0.075    -12.340      0.000      -1.068      -0.775
# ma.L1         -1.5344      0.140    -10.926      0.000      -1.810      -1.259
# ma.L2          0.6327      0.137      4.625      0.000       0.365       0.901
# ar.S.L12      -0.4018      0.144     -2.799      0.005      -0.683      -0.120
# ar.S.L24      -0.5582      0.120     -4.662      0.000      -0.793      -0.324
# sigma2        92.9368     19.458      4.776      0.000      54.799     131.074
# ===================================================================================
# Ljung-Box (Q):                       33.88   Jarque-Bera (JB):                 0.74
# Prob(Q):                              0.74   Prob(JB):                         0.69
# Heteroskedasticity (H):               0.70   Skew:                            -0.07
# Prob(H) (two-sided):                  0.39   Kurtosis:                         2.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_model.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Diagnostics");

# %%
fitted = pd.Series(arima_model.arima_res_.fittedvalues, index=train.index)
prediction = pd.DataFrame()
prediction = pd.DataFrame(arima_model.predict(n_periods=len(validation)), index=test.index)
prediction.columns = ['predicted']

plt.figure(figsize=(8, 5))
plt.plot(train, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(fitted, color="darkblue", label="ARIMA")
plt.plot(test, color="orange", label="Validação")
plt.plot(prediction, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA")
plt.legend(loc="upper left");

# %% [markdown]
# ### Modelo 2 -- ARIMA com Transformação de Box-Cox

# %%
from sklearn.preprocessing import PowerTransformer 

scaler = PowerTransformer(method="box-cox")
series_scaled = scaler.fit_transform(train.values.reshape(-1, 1))

# %%
arima_scaled = auto_arima(
    series_scaled,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=244.248, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=216.995, Time=0.43 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=243.012, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=220.940, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=202.317, Time=0.81 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=201.509, Time=1.55 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=203.504, Time=3.16 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=203.507, Time=1.93 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=201.949, Time=0.97 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=9.75 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=216.375, Time=0.93 sec
#  ARIMA(2,0,0)(3,1,0)[12] intercept   : AIC=201.669, Time=1.37 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=200.880, Time=2.41 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=200.467, Time=1.35 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=215.503, Time=0.49 sec
#  ARIMA(1,0,1)(2,1,1)[12] intercept   : AIC=201.189, Time=1.45 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=1.44 sec
#  ARIMA(1,0,1)(3,1,1)[12] intercept   : AIC=202.834, Time=2.67 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=208.368, Time=0.50 sec
#  ARIMA(2,0,1)(2,1,0)[12] intercept   : AIC=202.268, Time=2.29 sec
#  ARIMA(1,0,2)(2,1,0)[12] intercept   : AIC=202.032, Time=1.12 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=218.844, Time=0.34 sec
#  ARIMA(0,0,2)(2,1,0)[12] intercept   : AIC=208.200, Time=0.72 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=201.019, Time=0.80 sec
#  ARIMA(2,0,2)(2,1,0)[12] intercept   : AIC=200.921, Time=3.55 sec
#  ARIMA(1,0,1)(2,1,0)[12]             : AIC=198.983, Time=0.60 sec
#  ARIMA(1,0,1)(1,1,0)[12]             : AIC=213.840, Time=0.18 sec
#  ARIMA(1,0,1)(3,1,0)[12]             : AIC=199.252, Time=1.20 sec
#  ARIMA(1,0,1)(2,1,1)[12]             : AIC=199.659, Time=1.03 sec
#  ARIMA(1,0,1)(1,1,1)[12]             : AIC=inf, Time=0.61 sec
#  ARIMA(1,0,1)(3,1,1)[12]             : AIC=201.193, Time=2.21 sec
#  ARIMA(0,0,1)(2,1,0)[12]             : AIC=206.667, Time=0.29 sec
#  ARIMA(1,0,0)(2,1,0)[12]             : AIC=200.687, Time=0.37 sec
#  ARIMA(2,0,1)(2,1,0)[12]             : AIC=200.784, Time=1.93 sec
#  ARIMA(1,0,2)(2,1,0)[12]             : AIC=200.540, Time=0.78 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : AIC=217.068, Time=0.20 sec
#  ARIMA(0,0,2)(2,1,0)[12]             : AIC=206.545, Time=0.41 sec
#  ARIMA(2,0,0)(2,1,0)[12]             : AIC=199.487, Time=0.41 sec
#  ARIMA(2,0,2)(2,1,0)[12]             : AIC=199.080, Time=1.96 sec
#
# Best model:  ARIMA(1,0,1)(2,1,0)[12]
# Total fit time: 53.331 seconds

# %%
arima_scaled.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Scaled Diagnostics");

# %%
scale_fitted = pd.Series(arima_scaled.arima_res_.fittedvalues, index=train.index)
prediction_scaled = pd.DataFrame()
prediction_scaled = arima_scaled.predict(n_periods=len(validation))
prediction_scaled_series = pd.Series(prediction_scaled, index=test.index)
prediction_scaled_series.columns = ['predicted']
series_scaled_idx = pd.Series(series_scaled.reshape(1, -1)[0], index=train.index)
test_scaled_idx = pd.Series(scaler.transform(test.values.reshape(-1, 1)).reshape(1, -1)[0], index=test.index)

plt.figure(figsize=(8, 5))
plt.plot(series_scaled_idx, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(scale_fitted, color="darkblue", label="ARIMA")
plt.plot(test_scaled_idx, color="orange", label="Validação")
plt.plot(prediction_scaled_series, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA (Boxcox)")
plt.legend(loc="upper left");

# %%
inverted_prediction = scaler.inverse_transform(prediction_scaled.reshape(-1, 1))
inverted_prediction_series = pd.Series(inverted_prediction.reshape(1, -1)[0], index=test.index)

# %%
plt.figure(figsize=(8, 4))
plt.plot(test, color="orange", label="Valor Verdadeiro")
plt.plot(inverted_prediction_series, linestyle="--", color="green", label="Pred. com Boxcox")
plt.plot(prediction, linestyle="--", color="blue", label="Pred. sem Scaler")
plt.title(f"Comparação Predição de {col}")
plt.legend(loc="upper left");

# %%
metrics_df = pd.DataFrame({
    "sarima": round(rmse(test, prediction.values.flatten()), 3),
    "boxcox_sarima": round(rmse(test, inverted_prediction_series), 3)
}, index=["RMSE"])
metrics_df = metrics_df.T.sort_values("RMSE")
best_fit_name = metrics_df.reset_index()['index'][0]
metrics_df
# Out:
#                  RMSE
# boxcox_sarima  8.804
# sarima         11.579

# %%
boxcox_sarima = inverted_prediction_series
boxcox_sarima.name = col 
sarima = pd.Series(prediction['predicted'], index=validation.index)
sarima.name = col
arima = eval(best_fit_name)
# %store arima
# Out:
# Stored 'arima' (Series)

# %%
copy2("arima.ipynb", f"./models/arima/{name}_{col}.ipynb")
# Out:
# './models/arima/p1_NITROGÊNIO.ipynb'

# %%
arima_reset = arima.reset_index()
arima_reset.to_csv(f"./models/forecasts/{name}_{col}_arima.csv", sep=",", encoding="utf8", index=False)
