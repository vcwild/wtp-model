# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima import auto_arima, AutoARIMA
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from pmdarima.arima import ADFTest 
from statsmodels.tools.eval_measures import rmse
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
from pmdarima.arima import OCSBTest, ADFTest, ndiffs
from shutil import copy2
import warnings
# %matplotlib inline

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1) 

warnings.filterwarnings('ignore')

# %%
# Read file
path = "./datasets/"
name = "p1" # select dataset

df = pd.read_csv(path + name + "_clipped.csv", encoding='utf8', parse_dates=True, index_col="DATE")
validation = pd.read_csv(path + name + "_validation.csv", encoding='utf8', parse_dates=True, index_col="DATE")

cols = df.columns
col = cols[6] # select variable
series = df[col]

# %% [markdown]
# ## Verificação de Estacionareidade pelo teste ADF (Augmented Dickey-Fuller) e Número de Diferenciações por KPSS (Kwiatkowski – Phillips – Schmidt – Shin)

# %%
adf_test = ADFTest(alpha = 0.05)
adf = pd.DataFrame()
diff = pd.DataFrame()

for c in cols:
    adf[c] = adf_test.should_diff(df[c])
    diff[c] = [ndiffs(df[c], alpha=.05, test='kpss', max_d=2)]

adf = adf.T.rename(columns = {0: "adf_pval", 1: "non_stationary"})
diff = diff.T.rename(columns = {0: "d"})
diff = diff.T
adf = adf.T
adf = adf.append(diff)
adf
# Out:
#                 COLIFORMES_TERMOTOLERANTES       DQO  FÓSFORO  NITROGÊNIO  \
# adf_pval        0.36384                     0.038264  0.24594  0.178183
# non_stationary  1.00000                     0.000000  1.00000  1.000000
# d               1.00000                     0.000000  0.00000  0.000000
#
#                      DBO    PH  SURFACTANTES   SÓLIDOS     ÓLEOS  \
# adf_pval        0.076369  0.01  0.085174      0.083784  0.228793
# non_stationary  1.000000  0.00  1.000000      1.000000  1.000000
# d               0.000000  0.00  0.000000      1.000000  0.000000
#
#                 COR_VERDADEIRA
# adf_pval        0.01
# non_stationary  0.00
# d               1.00

# %% [markdown]
# ## Validação
# Para executar a validação vamos realizar fit em todo o conjunto disponível de dados e verificar a aproximação com os dados de validação da série histórica.

# %%
# train/test split
train = series 
test = validation[col]

# plot figures
plt.figure(figsize=(8, 4))
plt.plot(train, color="blue", label="Treino")
plt.plot(test, color="orange", label="Validação")
plt.legend(loc="upper left");
plt.title(f"Série Temporal {col}");

# %%
arima_model = auto_arima(
    train,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=121.535, Time=0.04 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=107.177, Time=0.31 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.99 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=119.536, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=120.197, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=103.922, Time=0.82 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=94.773, Time=1.46 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=96.440, Time=3.16 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=95.997, Time=2.72 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=2.99 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=12.53 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=93.862, Time=1.43 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=105.340, Time=1.13 sec
#  ARIMA(0,0,0)(4,1,0)[12] intercept   : AIC=95.623, Time=2.21 sec
#  ARIMA(0,0,0)(3,1,1)[12] intercept   : AIC=95.352, Time=2.82 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=1.96 sec
#  ARIMA(0,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=14.93 sec
#  ARIMA(0,0,1)(3,1,0)[12] intercept   : AIC=94.705, Time=2.03 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=96.702, Time=3.31 sec
#  ARIMA(0,0,0)(3,1,0)[12]             : AIC=92.311, Time=0.91 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : AIC=103.449, Time=0.32 sec
#  ARIMA(0,0,0)(4,1,0)[12]             : AIC=94.042, Time=1.90 sec
#  ARIMA(0,0,0)(3,1,1)[12]             : AIC=93.734, Time=3.57 sec
#  ARIMA(0,0,0)(2,1,1)[12]             : AIC=inf, Time=2.56 sec
#  ARIMA(0,0,0)(4,1,1)[12]             : AIC=inf, Time=8.26 sec
#  ARIMA(1,0,0)(3,1,0)[12]             : AIC=93.103, Time=1.00 sec
#  ARIMA(0,0,1)(3,1,0)[12]             : AIC=93.049, Time=0.85 sec
#  ARIMA(1,0,1)(3,1,0)[12]             : AIC=95.048, Time=2.38 sec
#
# Best model:  ARIMA(0,0,0)(3,1,0)[12]
# Total fit time: 76.683 seconds

# %%
print(arima_model.summary())
# Out:
#                                 SARIMAX Results
# ================================================================================
# Dep. Variable:                        y   No. Observations:                   84
# Model:             SARIMAX(3, 1, 0, 12)   Log Likelihood                 -42.155
# Date:                  Thu, 05 Nov 2020   AIC                             92.311
# Time:                          19:50:53   BIC                            101.417
# Sample:                               0   HQIC                            95.936
#                                    - 84
# Covariance Type:                    opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12      -0.7095      0.108     -6.564      0.000      -0.921      -0.498
# ar.S.L24      -0.5798      0.124     -4.672      0.000      -0.823      -0.337
# ar.S.L36      -0.5344      0.137     -3.887      0.000      -0.804      -0.265
# sigma2         0.1499      0.028      5.265      0.000       0.094       0.206
# ===================================================================================
# Ljung-Box (Q):                       28.78   Jarque-Bera (JB):                 1.13
# Prob(Q):                              0.91   Prob(JB):                         0.57
# Heteroskedasticity (H):               1.85   Skew:                             0.30
# Prob(H) (two-sided):                  0.14   Kurtosis:                         2.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_model.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Diagnostics");

# %%
fitted = pd.Series(arima_model.arima_res_.fittedvalues, index=train.index)
prediction = pd.DataFrame()
prediction = pd.DataFrame(arima_model.predict(n_periods=len(validation)), index=test.index)
prediction.columns = ['predicted']

plt.figure(figsize=(8, 5))
plt.plot(train, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(fitted, color="darkblue", label="ARIMA")
plt.plot(test, color="orange", label="Validação")
plt.plot(prediction, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA")
plt.legend(loc="upper left");

# %% [markdown]
# ### Modelo 2 -- ARIMA com Transformação de Box-Cox

# %%
from sklearn.preprocessing import PowerTransformer 

scaler = PowerTransformer(method="box-cox")
series_scaled = scaler.fit_transform(train.values.reshape(-1, 1))

# %%
arima_scaled = auto_arima(
    series_scaled,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=256.150, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=244.207, Time=0.47 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=254.157, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=255.275, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=240.692, Time=0.53 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=233.124, Time=1.36 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=234.971, Time=3.22 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=234.540, Time=2.43 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=9.98 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=232.198, Time=0.88 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=242.278, Time=0.38 sec
#  ARIMA(0,0,0)(4,1,0)[12] intercept   : AIC=234.076, Time=1.91 sec
#  ARIMA(0,0,0)(3,1,1)[12] intercept   : AIC=233.799, Time=2.36 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=2.42 sec
#  ARIMA(0,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=8.05 sec
#  ARIMA(0,0,1)(3,1,0)[12] intercept   : AIC=232.929, Time=1.08 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=234.862, Time=2.47 sec
#  ARIMA(0,0,0)(3,1,0)[12]             : AIC=230.964, Time=0.66 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : AIC=240.508, Time=0.17 sec
#  ARIMA(0,0,0)(4,1,0)[12]             : AIC=232.798, Time=1.16 sec
#  ARIMA(0,0,0)(3,1,1)[12]             : AIC=232.438, Time=1.61 sec
#  ARIMA(0,0,0)(2,1,1)[12]             : AIC=inf, Time=1.50 sec
#  ARIMA(0,0,0)(4,1,1)[12]             : AIC=inf, Time=7.17 sec
#  ARIMA(1,0,0)(3,1,0)[12]             : AIC=231.686, Time=0.76 sec
#  ARIMA(0,0,1)(3,1,0)[12]             : AIC=231.503, Time=0.74 sec
#  ARIMA(1,0,1)(3,1,0)[12]             : AIC=233.466, Time=2.10 sec
#
# Best model:  ARIMA(0,0,0)(3,1,0)[12]
# Total fit time: 56.794 seconds

# %%
arima_scaled.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Scaled Diagnostics");

# %%
scale_fitted = pd.Series(arima_scaled.arima_res_.fittedvalues, index=train.index)
prediction_scaled = pd.DataFrame()
prediction_scaled = arima_scaled.predict(n_periods=len(validation))
prediction_scaled_series = pd.Series(prediction_scaled, index=test.index)
prediction_scaled_series.columns = ['predicted']
series_scaled_idx = pd.Series(series_scaled.reshape(1, -1)[0], index=train.index)
test_scaled_idx = pd.Series(scaler.transform(test.values.reshape(-1, 1)).reshape(1, -1)[0], index=test.index)

plt.figure(figsize=(8, 5))
plt.plot(series_scaled_idx, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(scale_fitted, color="darkblue", label="ARIMA")
plt.plot(test_scaled_idx, color="orange", label="Validação")
plt.plot(prediction_scaled_series, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA (Boxcox)")
plt.legend(loc="upper left");

# %%
inverted_prediction = scaler.inverse_transform(prediction_scaled.reshape(-1, 1))
inverted_prediction_series = pd.Series(inverted_prediction.reshape(1, -1)[0], index=test.index)

# %%
plt.figure(figsize=(8, 4))
plt.plot(test, color="orange", label="Valor Verdadeiro")
plt.plot(inverted_prediction_series, linestyle="--", color="magenta", label="Pred. com Boxcox")
plt.plot(prediction, linestyle="--", color="blue", label="Pred. sem Scaler")
plt.title(f"Comparação Predição de {col}")
plt.legend(loc="upper left");

# %%
metrics_df = pd.DataFrame({
    "sarima": round(rmse(test, prediction.values.flatten()), 3),
    "boxcox_sarima": round(rmse(test, inverted_prediction_series), 3)
}, index=["RMSE"])
metrics_df = metrics_df.T.sort_values("RMSE")
best_fit_name = metrics_df.reset_index()['index'][0]
metrics_df
# Out:
#                 RMSE
# sarima         0.443
# boxcox_sarima  0.450

# %%
boxcox_sarima = inverted_prediction_series
boxcox_sarima.name = col 
sarima = pd.Series(prediction['predicted'], index=validation.index)
sarima.name = col
arima = eval(best_fit_name)
# %store arima
# Out:
# Stored 'arima' (Series)

# %%
copy2("arima.ipynb", f"./models/arima/{name}_{col}.ipynb")
# Out:
# './models/arima/p1_SURFACTANTES.ipynb'

# %%
arima_reset = arima.reset_index()
arima_reset.to_csv(f"./models/forecasts/{name}_{col}_arima.csv", sep=",", encoding="utf8", index=False)
