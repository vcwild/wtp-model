# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima import auto_arima, AutoARIMA
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from pmdarima.arima import ADFTest 
from statsmodels.tools.eval_measures import rmse
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
from pmdarima.arima import OCSBTest, ADFTest, ndiffs
from shutil import copy2
import warnings
# %matplotlib inline

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1) 

warnings.filterwarnings('ignore')

# %%
# Read file
path = "./datasets/"
name = "p1"

df = pd.read_csv(path + name + "_clipped.csv", encoding='utf8', parse_dates=True, index_col="DATE")
validation = pd.read_csv(path + name + "_validation.csv", encoding='utf8', parse_dates=True, index_col="DATE")

cols = df.columns
col = cols[5]
series = df[col]

# %% [markdown]
# ## Verificação de Estacionareidade pelo teste ADF (Augmented Dickey-Fuller) e Número de Diferenciações por KPSS (Kwiatkowski – Phillips – Schmidt – Shin)

# %%
adf_test = ADFTest(alpha = 0.05)
adf = pd.DataFrame()
diff = pd.DataFrame()

for c in cols:
    adf[c] = adf_test.should_diff(df[c])
    diff[c] = [ndiffs(df[c], alpha=.05, test='kpss', max_d=2)]

adf = adf.T.rename(columns = {0: "adf_pval", 1: "stationary"})
diff = diff.T.rename(columns = {0: "d"})
diff = diff.T
adf = adf.T
adf = adf.append(diff)
adf
# Out:
#             COLIFORMES_TERMOTOLERANTES       DQO  FÓSFORO  NITROGÊNIO  \
# adf_pval    0.36384                     0.038264  0.24594  0.178183
# stationary  1.00000                     0.000000  1.00000  1.000000
# d           1.00000                     0.000000  0.00000  0.000000
#
#                  DBO    PH  SURFACTANTES   SÓLIDOS     ÓLEOS  COR_VERDADEIRA
# adf_pval    0.076369  0.01  0.085174      0.083784  0.228793  0.01
# stationary  1.000000  0.00  1.000000      1.000000  1.000000  0.00
# d           0.000000  0.00  0.000000      1.000000  0.000000  1.00

# %% [markdown]
# ## Validação
# Para executar a validação vamos realizar fit em todo o conjunto disponível de dados e verificar a aproximação com os dados de validação da série histórica.

# %%
# train/test split
train = series 
test = validation[col]

# plot figures
plt.figure(figsize=(8, 4))
plt.plot(train, color="blue", label="Treino")
plt.plot(test, color="orange", label="Validação")
plt.legend(loc="upper left");
plt.title(f"Série Temporal {col}");
# Out:
# &lt;Figure size 576x288 with 1 Axes&gt;

# %%
arima_model = auto_arima(
    train,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=36.592, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=20.973, Time=0.39 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.79 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=34.651, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=37.931, Time=0.06 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=17.703, Time=1.18 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=9.917, Time=2.84 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=9.904, Time=4.52 sec
#  ARIMA(1,0,0)(5,1,0)[12] intercept   : AIC=inf, Time=12.82 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=11.443, Time=9.74 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=10.535, Time=3.53 sec
#  ARIMA(1,0,0)(5,1,1)[12] intercept   : AIC=13.320, Time=8.60 sec
#  ARIMA(0,0,0)(4,1,0)[12] intercept   : AIC=7.913, Time=3.67 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=8.106, Time=1.70 sec
#  ARIMA(0,0,0)(5,1,0)[12] intercept   : AIC=inf, Time=7.27 sec
#  ARIMA(0,0,0)(4,1,1)[12] intercept   : AIC=9.436, Time=8.39 sec
#  ARIMA(0,0,0)(3,1,1)[12] intercept   : AIC=8.580, Time=2.63 sec
#  ARIMA(0,0,0)(5,1,1)[12] intercept   : AIC=11.333, Time=7.47 sec
#  ARIMA(0,0,1)(4,1,0)[12] intercept   : AIC=9.905, Time=4.68 sec
#  ARIMA(1,0,1)(4,1,0)[12] intercept   : AIC=11.899, Time=9.04 sec
#  ARIMA(0,0,0)(4,1,0)[12]             : AIC=8.186, Time=2.74 sec
#
# Best model:  ARIMA(0,0,0)(4,1,0)[12] intercept
# Total fit time: 93.157 seconds

# %%
print(arima_model.summary())
# Out:
#                                 SARIMAX Results
# ================================================================================
# Dep. Variable:                        y   No. Observations:                   84
# Model:             SARIMAX(4, 1, 0, 12)   Log Likelihood                   2.043
# Date:                  Thu, 08 Oct 2020   AIC                              7.913
# Time:                          11:32:22   BIC                             21.573
# Sample:                               0   HQIC                            13.352
#                                    - 84
# Covariance Type:                    opg
# ==============================================================================
#                  coef    std err          z      P&gt;|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0574      0.040     -1.430      0.153      -0.136       0.021
# ar.S.L12      -0.9572      0.153     -6.259      0.000      -1.257      -0.657
# ar.S.L24      -0.7670      0.204     -3.751      0.000      -1.168      -0.366
# ar.S.L36      -0.7200      0.226     -3.179      0.001      -1.164      -0.276
# ar.S.L48      -0.2861      0.243     -1.177      0.239      -0.762       0.190
# sigma2         0.0420      0.010      4.209      0.000       0.022       0.062
# ===================================================================================
# Ljung-Box (Q):                       34.02   Jarque-Bera (JB):                 0.78
# Prob(Q):                              0.74   Prob(JB):                         0.68
# Heteroskedasticity (H):               2.08   Skew:                            -0.08
# Prob(H) (two-sided):                  0.08   Kurtosis:                         2.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_model.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Diagnostics");
# Out:
# &lt;Figure size 720x576 with 4 Axes&gt;

# %%
fitted = pd.Series(arima_model.arima_res_.fittedvalues, index=train.index)
prediction = pd.DataFrame()
prediction = pd.DataFrame(arima_model.predict(n_periods=len(validation)), index=test.index)
prediction.columns = ['predicted']

plt.figure(figsize=(8, 5))
plt.plot(train, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(fitted, color="darkblue", label="ARIMA")
plt.plot(test, color="orange", label="Validação")
plt.plot(prediction, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x360 with 1 Axes&gt;

# %% [markdown]
# ### Modelo 2 -- ARIMA com Transformação de Box-Cox

# %%
from sklearn.preprocessing import PowerTransformer 

scaler = PowerTransformer(method="box-cox")
series_scaled = scaler.fit_transform(train.values.reshape(-1, 1))

# %%
arima_scaled = auto_arima(
    series_scaled,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=256.748, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=241.928, Time=0.37 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.23 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=254.781, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=258.339, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=238.202, Time=0.68 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=230.774, Time=1.84 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=230.523, Time=3.74 sec
#  ARIMA(1,0,0)(5,1,0)[12] intercept   : AIC=232.258, Time=3.37 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=10.16 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=231.131, Time=2.82 sec
#  ARIMA(1,0,0)(5,1,1)[12] intercept   : AIC=234.257, Time=5.05 sec
#  ARIMA(0,0,0)(4,1,0)[12] intercept   : AIC=228.526, Time=2.68 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=228.862, Time=0.88 sec
#  ARIMA(0,0,0)(5,1,0)[12] intercept   : AIC=230.259, Time=2.52 sec
#  ARIMA(0,0,0)(4,1,1)[12] intercept   : AIC=inf, Time=8.36 sec
#  ARIMA(0,0,0)(3,1,1)[12] intercept   : AIC=229.134, Time=2.21 sec
#  ARIMA(0,0,0)(5,1,1)[12] intercept   : AIC=232.259, Time=3.22 sec
#  ARIMA(0,0,1)(4,1,0)[12] intercept   : AIC=230.523, Time=3.49 sec
#  ARIMA(1,0,1)(4,1,0)[12] intercept   : AIC=inf, Time=12.28 sec
#  ARIMA(0,0,0)(4,1,0)[12]             : AIC=229.272, Time=2.71 sec
#
# Best model:  ARIMA(0,0,0)(4,1,0)[12] intercept
# Total fit time: 67.721 seconds

# %%
arima_scaled.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Scaled Diagnostics");
# Out:
# &lt;Figure size 720x576 with 4 Axes&gt;

# %%
scale_fitted = pd.Series(arima_scaled.arima_res_.fittedvalues, index=train.index)
prediction_scaled = pd.DataFrame()
prediction_scaled = arima_scaled.predict(n_periods=len(validation))
prediction_scaled_series = pd.Series(prediction_scaled, index=test.index)
prediction_scaled_series.columns = ['predicted']
series_scaled_idx = pd.Series(series_scaled.reshape(1, -1)[0], index=train.index)
test_scaled_idx = pd.Series(scaler.transform(test.values.reshape(-1, 1)).reshape(1, -1)[0], index=test.index)

plt.figure(figsize=(8, 5))
plt.plot(series_scaled_idx, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(scale_fitted, color="darkblue", label="ARIMA")
plt.plot(test_scaled_idx, color="orange", label="Validação")
plt.plot(prediction_scaled_series, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA (Boxcox)")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x360 with 1 Axes&gt;

# %%
inverted_prediction = scaler.inverse_transform(prediction_scaled.reshape(-1, 1))
inverted_prediction_series = pd.Series(inverted_prediction.reshape(1, -1)[0], index=test.index)

# %%
plt.figure(figsize=(8, 4))
plt.plot(test, color="orange", label="Valor Verdadeiro")
plt.plot(inverted_prediction_series, linestyle="--", color="green", label="Pred. com Boxcox")
plt.plot(prediction, linestyle="--", color="blue", label="Pred. sem Scaler")
plt.title(f"Comparação Predição de {col}")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x288 with 1 Axes&gt;

# %%
metrics_df = pd.DataFrame({
    "sarima": round(rmse(test, prediction.values.flatten()), 3),
    "boxcox_sarima": round(rmse(test, inverted_prediction_series), 3)
}, index=["RMSE"])
metrics_df = metrics_df.T.sort_values("RMSE")
best_fit_name = metrics_df.reset_index()['index'][0]
metrics_df
# Out:
#                 RMSE
# boxcox_sarima  0.231
# sarima         0.234

# %%
boxcox_sarima = inverted_prediction_series
boxcox_sarima.name = col 
sarima = pd.Series(prediction['predicted'], index=validation.index)
sarima.name = col
arima = eval(best_fit_name)
# %store arima
# Out:
# Stored &#39;arima&#39; (Series)

# %%
copy2("arima.ipynb", f"./models/arima/{name}_{col}.ipynb")
# Out:
# &#39;./models/arima/p1_PH.ipynb&#39;
