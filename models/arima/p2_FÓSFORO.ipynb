# %% [markdown]
# ## Auto ARIMA

# %%
from pmdarima import auto_arima, AutoARIMA
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib import rcParams
from pmdarima.arima import ADFTest 
from statsmodels.tools.eval_measures import rmse
from pmdarima.pipeline import Pipeline
from pmdarima.preprocessing import BoxCoxEndogTransformer
from pmdarima.arima import OCSBTest, ADFTest, ndiffs
from shutil import copy2
import warnings
# %matplotlib inline

# Matplotlib options
rcParams['figure.figsize'] = (10, 8)
rcParams['axes.grid'] = False
plt.style.use('seaborn-deep')

# Pandas setup
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_colwidth', -1) 

warnings.filterwarnings('ignore')

# %%
# Read file
path = "./datasets/"
name = "p2"

df = pd.read_csv(path + name + "_clipped.csv", encoding='utf8', parse_dates=True, index_col="DATE")
validation = pd.read_csv(path + name + "_validation.csv", encoding='utf8', parse_dates=True, index_col="DATE")

cols = df.columns
col = cols[2]
series = df[col]

# %% [markdown]
# ## Verificação de Estacionareidade pelo teste ADF (Augmented Dickey-Fuller) e Número de Diferenciações por KPSS (Kwiatkowski – Phillips – Schmidt – Shin)

# %%
adf_test = ADFTest(alpha = 0.05)
adf = pd.DataFrame()
diff = pd.DataFrame()

for c in cols:
    adf[c] = adf_test.should_diff(df[c])
    diff[c] = [ndiffs(df[c], alpha=.05, test='kpss', max_d=2)]

adf = adf.T.rename(columns = {0: "adf_pval", 1: "stationary"})
diff = diff.T.rename(columns = {0: "d"})
diff = diff.T
adf = adf.T
adf = adf.append(diff)
adf
# Out:
#                  DQO  COLIFORMES_TERMOTOLERANTES  FÓSFORO  NITROGÊNIO   DBO  \
# adf_pval    0.023624  0.043021                    0.01     0.0381      0.01
# stationary  0.000000  0.000000                    0.00     0.0000      0.00
# d           0.000000  1.000000                    1.00     0.0000      0.00
#
#                   PH  SURFACTANTES   SÓLIDOS     ÓLEOS  COR_VERDADEIRA
# adf_pval    0.014383  0.032542      0.490253  0.083356  0.095539
# stationary  0.000000  0.000000      1.000000  1.000000  1.000000
# d           0.000000  1.000000      0.000000  0.000000  1.000000

# %% [markdown]
# ## Validação
# Para executar a validação vamos realizar fit em todo o conjunto disponível de dados e verificar a aproximação com os dados de validação da série histórica.

# %%
# train/test split
train = series 
test = validation[col]

# plot figures
plt.figure(figsize=(8, 4))
plt.plot(train, color="blue", label="Treino")
plt.plot(test, color="orange", label="Validação")
plt.legend(loc="upper left");
plt.title(f"Série Temporal {col}");
# Out:
# &lt;Figure size 576x288 with 1 Axes&gt;

# %%
arima_model = auto_arima(
    train,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=356.750, Time=0.04 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=317.646, Time=0.16 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.90 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=340.523, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=308.127, Time=0.57 sec
#  ARIMA(1,1,0)(3,1,0)[12]             : AIC=310.066, Time=0.94 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=310.060, Time=0.80 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=310.062, Time=0.42 sec
#  ARIMA(1,1,0)(3,1,1)[12]             : AIC=inf, Time=6.17 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=321.122, Time=0.34 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=303.490, Time=0.66 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=309.450, Time=0.36 sec
#  ARIMA(2,1,0)(3,1,0)[12]             : AIC=305.318, Time=1.48 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=305.322, Time=1.18 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=304.284, Time=0.47 sec
#  ARIMA(2,1,0)(3,1,1)[12]             : AIC=inf, Time=6.20 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=298.758, Time=0.63 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=304.454, Time=0.19 sec
#  ARIMA(3,1,0)(3,1,0)[12]             : AIC=300.569, Time=1.25 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=300.538, Time=1.23 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=299.168, Time=0.48 sec
#  ARIMA(3,1,0)(3,1,1)[12]             : AIC=inf, Time=8.22 sec
#  ARIMA(4,1,0)(2,1,0)[12]             : AIC=299.228, Time=0.79 sec
#  ARIMA(3,1,1)(2,1,0)[12]             : AIC=293.789, Time=1.88 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=299.346, Time=0.67 sec
#  ARIMA(3,1,1)(3,1,0)[12]             : AIC=294.949, Time=3.84 sec
#  ARIMA(3,1,1)(2,1,1)[12]             : AIC=294.650, Time=1.88 sec
#  ARIMA(3,1,1)(1,1,1)[12]             : AIC=292.762, Time=1.63 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=inf, Time=2.85 sec
#  ARIMA(3,1,1)(1,1,2)[12]             : AIC=294.724, Time=2.78 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=inf, Time=0.25 sec
#  ARIMA(3,1,1)(0,1,2)[12]             : AIC=292.729, Time=1.49 sec
#  ARIMA(3,1,1)(0,1,3)[12]             : AIC=294.718, Time=2.84 sec
#  ARIMA(3,1,1)(1,1,3)[12]             : AIC=inf, Time=7.01 sec
#  ARIMA(2,1,1)(0,1,2)[12]             : AIC=290.859, Time=1.55 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=inf, Time=1.34 sec
#  ARIMA(2,1,1)(1,1,2)[12]             : AIC=292.858, Time=2.57 sec
#  ARIMA(2,1,1)(0,1,3)[12]             : AIC=292.857, Time=3.21 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=290.914, Time=1.38 sec
#  ARIMA(2,1,1)(1,1,3)[12]             : AIC=inf, Time=8.22 sec
#  ARIMA(1,1,1)(0,1,2)[12]             : AIC=inf, Time=2.50 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=303.946, Time=1.34 sec
#  ARIMA(2,1,2)(0,1,2)[12]             : AIC=inf, Time=2.76 sec
#  ARIMA(1,1,0)(0,1,2)[12]             : AIC=309.786, Time=0.75 sec
#  ARIMA(1,1,2)(0,1,2)[12]             : AIC=inf, Time=3.31 sec
#  ARIMA(3,1,0)(0,1,2)[12]             : AIC=298.980, Time=1.04 sec
#  ARIMA(3,1,2)(0,1,2)[12]             : AIC=294.607, Time=1.96 sec
#  ARIMA(2,1,1)(0,1,2)[12] intercept   : AIC=292.857, Time=2.86 sec
#
# Best model:  ARIMA(2,1,1)(0,1,2)[12]
# Total fit time: 95.476 seconds

# %%
print(arima_model.summary())
# Out:
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                   84
# Model:             SARIMAX(2, 1, 1)x(0, 1, [1, 2], 12)   Log Likelihood                -139.430
# Date:                                 Thu, 08 Oct 2020   AIC                            290.859
# Time:                                         07:47:54   BIC                            304.435
# Sample:                                              0   HQIC                           296.258
#                                                   - 84
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P&gt;|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0728      0.132      0.550      0.582      -0.187       0.332
# ar.L2         -0.0588      0.146     -0.403      0.687      -0.345       0.227
# ma.L1         -0.9291      0.100     -9.259      0.000      -1.126      -0.732
# ma.S.L12      -0.8875      0.145     -6.125      0.000      -1.172      -0.603
# ma.S.L24       0.2037      0.156      1.301      0.193      -0.103       0.510
# sigma2         2.4693      0.562      4.395      0.000       1.368       3.570
# ===================================================================================
# Ljung-Box (Q):                       16.81   Jarque-Bera (JB):                 2.20
# Prob(Q):                              1.00   Prob(JB):                         0.33
# Heteroskedasticity (H):               0.54   Skew:                             0.27
# Prob(H) (two-sided):                  0.14   Kurtosis:                         2.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
arima_model.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Diagnostics");
# Out:
# &lt;Figure size 720x576 with 4 Axes&gt;

# %%
fitted = pd.Series(arima_model.arima_res_.fittedvalues, index=train.index)
prediction = pd.DataFrame()
prediction = pd.DataFrame(arima_model.predict(n_periods=len(validation)), index=test.index)
prediction.columns = ['predicted']

plt.figure(figsize=(8, 5))
plt.plot(train, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(fitted, color="darkblue", label="ARIMA")
plt.plot(test, color="orange", label="Validação")
plt.plot(prediction, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x360 with 1 Axes&gt;

# %% [markdown]
# ### Modelo 2 -- ARIMA com Transformação de Box-Cox

# %%
from sklearn.preprocessing import PowerTransformer 

scaler = PowerTransformer(method="box-cox")
series_scaled = scaler.fit_transform(train.values.reshape(-1, 1))

# %%
arima_scaled = auto_arima(
    series_scaled,
    start_p=0,
    d=int(adf[col].d),
    start_q=0,
    max_p=5,
    max_d=5,
    max_q=5,
    start_P=0,
    D=1,
    start_Q=0,
    max_P=5,
    max_D=5,
    max_Q=5,
    m=12,
    seasonal=True,
    error_action='warn',
    trace=True,
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    maxiter=50,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=281.100, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=242.126, Time=0.18 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.66 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=265.047, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=232.435, Time=0.34 sec
#  ARIMA(1,1,0)(3,1,0)[12]             : AIC=234.391, Time=0.70 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=234.386, Time=0.74 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=234.491, Time=0.31 sec
#  ARIMA(1,1,0)(3,1,1)[12]             : AIC=inf, Time=5.81 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=245.462, Time=0.27 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=228.148, Time=0.60 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=234.252, Time=0.29 sec
#  ARIMA(2,1,0)(3,1,0)[12]             : AIC=229.974, Time=1.03 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=229.975, Time=0.93 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=228.963, Time=0.38 sec
#  ARIMA(2,1,0)(3,1,1)[12]             : AIC=inf, Time=6.32 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=224.049, Time=0.51 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=230.087, Time=0.23 sec
#  ARIMA(3,1,0)(3,1,0)[12]             : AIC=225.838, Time=1.08 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=225.796, Time=1.05 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=224.454, Time=0.49 sec
#  ARIMA(3,1,0)(3,1,1)[12]             : AIC=inf, Time=6.87 sec
#  ARIMA(4,1,0)(2,1,0)[12]             : AIC=224.576, Time=0.66 sec
#  ARIMA(3,1,1)(2,1,0)[12]             : AIC=219.111, Time=1.14 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=224.970, Time=0.56 sec
#  ARIMA(3,1,1)(3,1,0)[12]             : AIC=220.253, Time=2.44 sec
#  ARIMA(3,1,1)(2,1,1)[12]             : AIC=219.927, Time=2.41 sec
#  ARIMA(3,1,1)(1,1,1)[12]             : AIC=218.081, Time=1.55 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=inf, Time=2.02 sec
#  ARIMA(3,1,1)(1,1,2)[12]             : AIC=220.027, Time=3.12 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=inf, Time=0.25 sec
#  ARIMA(3,1,1)(0,1,2)[12]             : AIC=218.027, Time=1.52 sec
#  ARIMA(3,1,1)(0,1,3)[12]             : AIC=220.026, Time=2.81 sec
#  ARIMA(3,1,1)(1,1,3)[12]             : AIC=inf, Time=8.23 sec
#  ARIMA(2,1,1)(0,1,2)[12]             : AIC=inf, Time=0.93 sec
#  ARIMA(3,1,0)(0,1,2)[12]             : AIC=224.261, Time=0.79 sec
#  ARIMA(4,1,1)(0,1,2)[12]             : AIC=inf, Time=6.78 sec
#  ARIMA(3,1,2)(0,1,2)[12]             : AIC=219.939, Time=4.83 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=228.626, Time=1.17 sec
#  ARIMA(2,1,2)(0,1,2)[12]             : AIC=inf, Time=3.45 sec
#  ARIMA(4,1,0)(0,1,2)[12]             : AIC=224.296, Time=1.43 sec
#  ARIMA(4,1,2)(0,1,2)[12]             : AIC=inf, Time=4.82 sec
#  ARIMA(3,1,1)(0,1,2)[12] intercept   : AIC=220.025, Time=4.08 sec
#
# Best model:  ARIMA(3,1,1)(0,1,2)[12]
# Total fit time: 83.854 seconds

# %%
arima_scaled.plot_diagnostics()
plt.suptitle(f"{col} ARIMA Scaled Diagnostics");
# Out:
# &lt;Figure size 720x576 with 4 Axes&gt;

# %%
scale_fitted = pd.Series(arima_scaled.arima_res_.fittedvalues, index=train.index)
prediction_scaled = pd.DataFrame()
prediction_scaled = arima_scaled.predict(n_periods=len(validation))
prediction_scaled_series = pd.Series(prediction_scaled, index=test.index)
prediction_scaled_series.columns = ['predicted']
series_scaled_idx = pd.Series(series_scaled.reshape(1, -1)[0], index=train.index)
test_scaled_idx = pd.Series(scaler.transform(test.values.reshape(-1, 1)).reshape(1, -1)[0], index=test.index)

plt.figure(figsize=(8, 5))
plt.plot(series_scaled_idx, color="grey", linestyle=":", alpha=0.8, label="Treino")
plt.plot(scale_fitted, color="darkblue", label="ARIMA")
plt.plot(test_scaled_idx, color="orange", label="Validação")
plt.plot(prediction_scaled_series, linestyle="--", color="darkblue", label="Predito")
plt.title(f"Predição de {col} por SARIMA (Boxcox)")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x360 with 1 Axes&gt;

# %%
inverted_prediction = scaler.inverse_transform(prediction_scaled.reshape(-1, 1))
inverted_prediction_series = pd.Series(inverted_prediction.reshape(1, -1)[0], index=test.index)

# %%
plt.figure(figsize=(8, 4))
plt.plot(test, color="orange", label="Valor Verdadeiro")
plt.plot(inverted_prediction_series, linestyle="--", color="green", label="Pred. com Boxcox")
plt.plot(prediction, linestyle="--", color="blue", label="Pred. sem Scaler")
plt.title(f"Comparação Predição de {col}")
plt.legend(loc="upper left");
# Out:
# &lt;Figure size 576x288 with 1 Axes&gt;

# %%
metrics_df = pd.DataFrame({
    "sarima": round(rmse(test, prediction.values.flatten()), 3),
    "boxcox_sarima": round(rmse(test, inverted_prediction_series), 3)
}, index=["RMSE"])
metrics_df = metrics_df.T.sort_values("RMSE")
best_fit_name = metrics_df.reset_index()['index'][0]
metrics_df
# Out:
#                 RMSE
# boxcox_sarima  1.655
# sarima         1.719

# %%
boxcox_sarima = inverted_prediction_series
boxcox_sarima.name = col 
sarima = pd.Series(prediction['predicted'], index=validation.index)
sarima.name = col
arima = eval(best_fit_name)
# %store arima
# Out:
# Stored &#39;arima&#39; (Series)

# %%
copy2("arima.ipynb", f"./models/arima/{name}_{col}.ipynb")
# Out:
# &#39;./models/arima/p2_FÓSFORO.ipynb&#39;
